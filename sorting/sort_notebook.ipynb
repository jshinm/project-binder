# %% [markdown]
# # Sorting Algorithm Implementations

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dset = np.random.choice(5000, 5000, replace=False)
idx = np.arange(start=0, stop=len(dset))

# %%
def plot(arr=None, func=None):
    if arr is not None:
        out = func(arr)
        fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(5*2,5))
        ax[0].scatter(x=idx, y=dset, s=2)
        ax[1].scatter(x=idx, y=out, s=2)
    else:        
        fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5*1,5))
        ax.scatter(x=idx, y=dset, s=2)

# %%
plot()

# %% [markdown]
# ## Bubble Sort

# %%
def bubbleSort(dat):
    arr = dat.copy() #prevent in-place sorting
    l = len(arr) #length of array
    swapped = False

    for i in range(l-1,0,-1):
        for j in range(i):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
                swapped = True
        if swapped:
            swapped = False
        else:
            break
    return arr

# %%
# %%timeit -n 1 -r 1
bubbleSort(dset)
# Out:
# 8.06 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
plot(dset, bubbleSort)

# %% [markdown]
# ## Insertion Sort

# %%
def insertionSort(dat):
    arr = dat.copy() #prevent in-place sorting
    l = len(arr)

    for i in range(1, l):
        key = arr[i]
        for j in range(i-1,-1,-1):
            if arr[j] > key:
                arr[j+1] = arr[j]
            else:
                break
        arr[j] = key
    return arr

# %%
# %%timeit -n 1 -r 1
out = insertionSort(dset)
# Out:
# 2.83 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
plot(dset, insertionSort)
